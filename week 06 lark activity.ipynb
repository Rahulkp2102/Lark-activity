# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Dataset_w6.xlsx')

# %%
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# # no.of countries

# %%
data.isnull().sum()
# Out:
# country                                       0
# Region                                        0
# Surface area (km2)                            0
# Population in thousands (2017)                0
# GDP per capita (current US$)                  0
# Agricultural production index                 0
# International trade: Imports (million US$)    0
# dtype: int64

# %%
len(data['country'])
# Out:
# 196

# %% [markdown]
# # visualization

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='country',y='Population in thousands (2017)',data=data.sort_values('Population in thousands (2017)',ascending=False).head(10))
plt.title('countries vs population',fontsize=20)
plt.xlabel('countries')
plt.ylabel('population')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
sns.barplot(x='country',y='Agricultural production index ',data=data.sort_values('Agricultural production index ').head(10),color='blue') 
plt.title('Top 10 countries VS Agricultural production',fontweight='bold',fontsize=18)
plt.xlabel('Country')
plt.ylabel('Agricultural production index')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(data['Region'],data['International trade: Imports (million US$)'],s=10,c='green')
plt.title('Plot of Region VS International Trade',fontweight='bold',fontsize=18)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('International Trade')
# Out:
# Text(0, 0.5, 'International Trade')

# %% [markdown]
# # no.of countries with respect to region

# %%
data.groupby('Region')[['country']].count()
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %% [markdown]
# # region having highest

# %%
#GDP per capita (current US$)

# %%
gdp=data.groupby('Region')[['GDP per capita (current US$)']].mean()
gdp.sort_values('GDP per capita (current US$)',ascending=False)
# Out:
#                    GDP per capita (current US$)
# Region
# NorthernAmerica                    57659.000000
# WesternEurope                      55387.128571
# Oceania                            44823.250000
# NorthernEurope                     42098.220000
# EasternAsia                        27967.614286
# WesternAsia                        17013.938889
# Caribbean                          15135.562500
# SouthernEurope                     14462.741667
# South-easternAsia                  10299.027273
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Polynesia                           8686.520000
# SouthAmerica                        8499.775000
# CentralAmerica                      6348.137500
# Micronesia                          5008.300000
# CentralAsia                         4329.880000
# SouthernAfrica                      4191.900000
# NorthernAfrica                      3934.960000
# ...

# %%
# International trade: Imports (million US$)

# %%
iti=data.groupby('Region')[['International trade: Imports (million US$)']].mean()
iti.sort_values('International trade: Imports (million US$)',ascending=False)
# Out:
#                    International trade: Imports (million US$)
# Region
# NorthernAmerica                                 663552.250000
# EasternAsia                                     451995.000000
# WesternEurope                                   407498.428571
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# South-easternAsia                                98324.636364
# EasternEurope                                    85243.900000
# SouthernEurope                                   76666.666667
# SouthernAsia                                     58199.333333
# CentralAmerica                                   57031.500000
# WesternAsia                                      46025.555556
# NorthernAfrica                                   35034.400000
# SouthAmerica                                     32885.666667
# SouthernAfrica                                   18005.600000
# ...

# %% [markdown]
# # region more consistant with respect to GDP per capita (current US$)

# %%
con_gdp=data.groupby('Region')[['GDP per capita (current US$)']].std()
con_gdp.sort_values('GDP per capita (current US$)',ascending=True)
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# WesternAsia                        18812.151459
# ...
